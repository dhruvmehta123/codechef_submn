# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("sales_data.csv")
df
# Out:
#      ID Product  Quantity  Revenue
# 0     1       B         5       80
# 1     2       B         8      163
# 2     3       A         2       94
# 3     4       B         2       53
# 4     5       C         3      170
# ..  ...     ...       ...      ...
# 95   96       A         3      138
# 96   97       A         3       79
# 97   98       A         6       89
# 98   99       A         9      121
# 99  100       C         5       54
#
# [100 rows x 4 columns]

# %%
#Task 1 (a)
plt.plot(df['ID'],df['Revenue'])
plt.xlabel('ID')
plt.ylabel('Revenue')
# Out:
# Text(0, 0.5, 'Revenue')

# %%
#Task 1 (b)
plt.scatter(df['Revenue'],df['Quantity'])
plt.xlabel('Revenue')
plt.ylabel('Quantity')
# Out:
# Text(0, 0.5, 'Quantity')

# %%
#task 1 (c)
product_category_revenue = df.groupby('Product')['Revenue'].sum()
plt.figure(figsize=(10, 6))
product_category_revenue.plot(kind='bar')
plt.title('Total Revenue for Each Product Category')
plt.xlabel('Product Category')
plt.ylabel('Total Revenue')
# Out:
# Text(0, 0.5, 'Total Revenue')
